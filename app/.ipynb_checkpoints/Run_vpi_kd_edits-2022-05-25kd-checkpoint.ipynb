# %%
import os
import sys
import tkinter
import time
import numpy
import csv

# %%
import sys
from collections import deque
from threading import Thread

from config.Configuration import env
from resources.LeapSDK.v53_python39 import Leap

# %%
from LeapData import LeapData

# %%
class SampleListener(Leap.Listener):
    finger_names = ['Thumb', 'Index', 'Middle', 'Ring', 'Pinky']
    bone_names = ['Metacarpal', 'Proximal', 'Intermediate', 'Distal']

    def on_init(self, controller):
        print("Initialized")

    def on_connect(self, controller):
        print("Connected")

    def on_disconnect(self, controller):
        # Note: not dispatched when running in a debugger.
        print("Disconnected")

    def on_exit(self, controller):
        print("Exited")

    def on_frame(self, controller):
        # Get the most recent frame and report some basic information
        frame = controller.frame()

        print("Frame id: %d, timestamp: %d, hands: %d, fingers: %d" % (
              frame.id, frame.timestamp, len(frame.hands), len(frame.fingers)))

        # Get hands
        for hand in frame.hands:

            handType = "Left hand" if hand.is_left else "Right hand"

            print("  %s, id %d, position: %s" % (
                handType, hand.id, hand.palm_position))

            # Get the hand's normal vector and direction
            normal = hand.palm_normal
            direction = hand.direction

            # Calculate the hand's pitch, roll, and yaw angles
            print("  pitch: %f degrees, roll: %f degrees, yaw: %f degrees" % (
                direction.pitch * Leap.RAD_TO_DEG,
                normal.roll * Leap.RAD_TO_DEG,
                direction.yaw * Leap.RAD_TO_DEG))

            # Get arm bone
            arm = hand.arm
            print("  Arm direction: %s, wrist position: %s, elbow position: %s" % (
                arm.direction,
                arm.wrist_position,
                arm.elbow_position))

            # Get fingers
            for finger in hand.fingers:

                print("    %s finger, id: %d, length: %fmm, width: %fmm" % (
                    self.finger_names[finger.type],
                    finger.id,
                    finger.length,
                    finger.width))

                # Get bones
                for b in range(0, 4):
                    bone = finger.bone(b)
                    print("      Bone: %s, start: %s, end: %s, direction: %s" % (
                        self.bone_names[bone.type],
                        bone.prev_joint,
                        bone.next_joint,
                        bone.direction))

        if not frame.hands.is_empty:
            print("")

# %%
# Set up Leap Controller and Listener
c = Leap.Controller()
l = SampleListener()

controller = Leap.Controller()
controller.add_listener(l)
# Out:
# Initialized
# True

# %%
# hkb parameters from: Kelso et al. (PLos ONE, 2009)
mu = -1
A = 3
B = -0.025
omega0 = numpy.pi
omega = 1.5 * numpy.pi
alpha = 0.642
beta = 0.00709
gamma = 12.457

# visualisation parameters
width = 640
height = 480

# variables initialisation with human(x) & virtual_partner(y)
dt = 1 / 100
x_pos = width / 2
x = 0
xd = 0
xdd = 0
xlast = 0
y_pos = width / 3
y = 0
yd = 0.01
ydd = 0
count = 0
start = time.time()
datax, datay = [], []

# canvas construction
w = tkinter.Tk()
# w.config(cursor="none")
can = tkinter.Canvas(w, width=width, height=height, background='black')
ligne1 = can.create_line(width / 10 * 2, height / 10 * 3,
                       width / 10 * 8, height / 10 * 3,
                       width=2, fill='white')
line11 = can.create_line(width / 10 * 2, height / 10 * 2.7,
                       width / 10 * 2, height / 10 * 3.3,
                       width=2, fill='white')
line12 = can.create_line(width / 10 * 8, height / 10 * 2.7,
                       width / 10 * 8, height / 10 * 3.3,
                       width=2, fill='white')
line2 = can.create_line(width / 10 * 2, height / 10 * 7,
                      width / 10 * 8, height / 10 * 7,
                      width=2, fill='white')
line21 = can.create_line(width / 10 * 2, height / 10 * 6.7,
                       width / 10 * 2, height / 10 * 7.3,
                       width=2, fill='white')
line22 = can.create_line(width / 10 * 8, height / 10 * 6.7,
                       width / 10 * 8, height / 10 * 7.3,
                       width=2, fill='white')
red = can.create_oval(width / 10 * 5 - height / 20, height / 10 * 7 - height / 20,
                    width / 10 * 5 + height / 20, height / 10 * 7 + height / 20,
                    fill='#D90F0F')
blue = can.create_oval(width / 10 * 5 - height / 20, height / 10 * 3 - height / 20,
                     width / 10 * 5 + height / 20, height / 10 * 3 + height / 20,
                     fill='#008F8F')
# isoluminance of the partners color based on:
# Kindlmann, Reinhard, & Creem. (2002)

# %%
def leap_poll_listener():
    frame = controller.frame()

    print("Frame id: %d, timestamp: %d, hands: %d, fingers: %d" % (
              frame.id, frame.timestamp, len(frame.hands), len(frame.fingers)))

    # Get hands
    for hand in frame.hands:

            handType = "Left hand" if hand.is_left else "Right hand"

            print("  %s, id %d, position: %s" % (
                handType, hand.id, hand.palm_position))

            # Get the hand's normal vector and direction
            normal = hand.palm_normal
            direction = hand.direction

# %%
def main():
    """ main loop updating and recording circles positions """
    move_human()
    move_virtual()
    datax.append(x)
    datay.append(y)
    w.after(10, main)


def close(event):
    """ quit the program with esc """
    write()
    sys.exit()


def move_human():
    """ move human red circle and bound it """
    get_motion_human()
    if x_pos < width / 10 * 2:
        can.coords(red, width / 10 * 2 - height / 20, height / 10 * 7 - height / 20,
                      width / 10 * 2 + height / 20, height / 10 * 7 + height / 20)
    elif x_pos > width / 10 * 8:
        can.coords(red, width / 10 * 8 - height / 20, height / 10 * 7 - height / 20,
                      width / 10 * 8 + height / 20, height / 10 * 7 + height / 20)
    else:
        can.coords(red, x_pos - height / 20, height / 10 * 7 - height / 20,
                      x_pos + height / 20, height / 10 * 7 + height / 20)


def get_motion_human():
    global x_pos
    """ get position of human player hand through leap motion """
    event = leap_poll_listener()
    if event:
        e = Event(event)
        if e:
            if any(e.frame.hands):
                x_pos = e.frame.hands[0].palm_position.points[0] * width / 600 + width / 2

def move_virtual():
    """ move virtual player blue circle """
    calcul_virtual()
    y_pos = y * (width / 22) + width / 2
    can.coords(blue, y_pos - height / 20, height / 10 * 3 - height / 20,
                   y_pos + height / 20, height / 10 * 3 + height / 20)


def calcul_virtual():
    """ update virtual position """
    global count, dt
    now = time.time()
    count += 1
    dt = 1 / (count / (now - start))
    human_velocity()
    update_hkb()


def human_velocity():
    """ get human motion information for hkb """
    global x, xd, xlast
    x = (x_pos - width / 2) / (width / 10 * 3)
    xd = (xlast - x) / 0.005
    xlast = x


def update_hkb():
    """ calcul virtual motion information with hkb model """
    global y, yd, omega
    ydd = (A + B * (y - mu * x)**2) * (yd - mu * xd) - omega**2 * y \
        - (alpha * y**2 + beta * yd**2 - gamma) * yd
    yd += dt * ydd
    y += dt * yd


def write():
    writer = csv.writer(open('gauche1.csv', 'wb'))
    writer.writerow(('count', 'human', 'vp'))
    for i in range(len(datax)):
      writer.writerow((i, datax[i], datay[i]))

# %%
main()
can.focus_set()
w.bind('<Escape>', close)
can.pack()
w.mainloop()
# Out:
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Frame id: -1, timestamp: 0, hands: 0, fingers: 0
# Connected
# Frame id: 571, timestamp: 988236891060, hands: 0, fingers: 0
# Frame id: 572, timestamp: 988236899820, hands: 0, fingers: 0
# Frame id: 573, timestamp: 988236908309, hands: 0, fingers: 0
# Frame id: 574, timestamp: 988236917118, hands: 0, fingers: 0
# Frame id: 575, timestamp: 988236926028, hands: 0, fingers: 0
# Frame id: 574, timestamp: 988236917118, hands: 0, fingers: 0
# Frame id: 576, timestamp: 988236934385, hands: 0, fingers: 0
# Frame id: 577, timestamp: 988236943376, hands: 0, fingers: 0
# Frame id: 578, timestamp: 988236951753, hands: 0, fingers: 0
# Frame id: 579, timestamp: 988236960473, hands: 0, fingers: 0
# Frame id: 580, timestamp: 988236969190, hands: 0, fingers: 0
# Frame id: 581, timestamp: 988236977824, hands: 0, fingers: 0
# Frame id: 582, timestamp: 988236986453, hands: 0, fingers: 0Frame id: 582, timestamp: 988236986453, hands: 0, fingers: 0
#
# Frame id: 583, timestamp: 988236995086, hands: 0, fingers: 0
# Frame id: 584, timestamp: 988237003821, hands: 0, fingers: 0
# Frame id: 585, timestamp: 988237012545, hands: 0, fingers: 0
# Frame id: 586, timestamp: 988237021300, hands: 0, fingers: 0
# Frame id: 587, timestamp: 988237029856, hands: 0, fingers: 0
# Frame id: 588, timestamp: 988237038905, hands: 0, fingers: 0
# Frame id: 588, timestamp: 988237038905, hands: 0, fingers: 0
# Frame id: 589, timestamp: 988237047199, hands: 0, fingers: 0
# Frame id: 590, timestamp: 988237056362, hands: 0, fingers: 0
# Frame id: 591, timestamp: 988237064399, hands: 1, fingers: 5
#   Left hand, id 3, position: (-161.665, 143.375, -8.17276)
#   pitch: 18.202347 degrees, roll: 75.139527 degrees, yaw: -17.380670 degrees
#   Arm direction: (0.564825, -0.159221, -0.809705), wrist position: (-156.794, 122.413, 53.5885), elbow position: (-290.502, 160.105, 245.267)
#     Thumb finger, id: 30, length: 37.276718mm, width: 17.754477mm
#       Bone: Metacarpal, start: (-141.82, 143.051, 38.0918), end: (-141.82, 143.051, 38.0918), direction: (0, 0, 0)
#       Bone: Proximal, start: (-141.82, 143.051, 38.0918), end: (-130.074, 171.885, 5.27028), direction: (0.259647, 0.637368, -0.725497)
#       Bone: Intermediate, start: (-130.074, 171.885, 5.27028), end: (-122.359, 178.942, -17.0986), direction: (0.312453, 0.285814, -0.905916)
#       Bone: Distal, start: (-122.359, 178.942, -17.0986), end: (-117.554, 176.04, -32.4482), direction: (0.293956, -0.177606, -0.939173)
#     Index finger, id: 31, length: 42.431744mm, width: 16.959076mm
#       Bone: Metacarpal, start: (-157.637, 142.48, 36.1895), end: (-163.444, 168.913, -22.3618), direction: (-0.0900366, 0.409787, -0.907727)
#       Bone: Proximal, start: (-163.444, 168.913, -22.3618), end: (-151.527, 170.003, -48.5368), direction: (0.414067, 0.0378674, -0.909459)
#       Bone: Intermediate, start: (-151.527, 170.003, -48.5368), end: (-135.794, 163.665, -51.555), direction: (0.913228, -0.367862, -0.175192)
#       Bone: Distal, start: (-135.794, 163.665, -51.555), end: (-124.752, 156.702, -46.3763), direction: (0.786242, -0.495833, 0.368745)
#     Middle finger, id: 32, length: 50.480915mm, width: 16.656065mm
#       Bone: Metacarpal, start: (-162.57, 136.529, 31.8667), end: (-171.035, 154.131, -26.1011), direction: (-0.138396, 0.287758, -0.947651)
#       Bone: Proximal, start: (-171.035, 154.131, -26.1011), end: (-158.285, 154.286, -56.1972), direction: (0.390088, 0.00473506, -0.920765)
#       Bone: Intermediate, start: (-158.285, 154.286, -56.1972), end: (-137.049, 148.456, -60.1837), direction: (0.948904, -0.260479, -0.178132)
#       Bone: Distal, start: (-137.049, 148.456, -60.1837), end: (-124.041, 142.741, -54.5875), direction: (0.851845, -0.374261, 0.366454)
#     Ring finger, id: 33, length: 42.728851mm, width: 15.849302mm
#       Bone: Metacarpal, start: (-164.65, 126.291, 27.36), end: (-174.84, 134.328, -26.0051), direction: (-0.185541, 0.146331, -0.97168)
#       Bone: Proximal, start: (-174.84, 134.328, -26.0051), end: (-161.519, 135.639, -54.9444), direction: (0.417784, 0.0411043, -0.907616)
#       Bone: Intermediate, start: (-161.519, 135.639, -54.9444), end: (-145.004, 133.757, -58.3261), direction: (0.973626, -0.110931, -0.199367)
#       Bone: Distal, start: (-145.004, 133.757, -58.3261), end: (-133.225, 131.333, -54.0643), direction: (0.923211, -0.190021, 0.334027)
#     Pinky finger, id: 34, length: 35.640461mm, width: 14.078589mm
#       Bone: Metacarpal, start: (-159.89, 115.667, 27.3489), end: (-173.245, 116.815, -21.6916), direction: (-0.262684, 0.0225834, -0.964618)
#       Bone: Proximal, start: (-173.245, 116.815, -21.6916), end: (-165.056, 120.194, -42.359), direction: (0.364188, 0.150284, -0.91912)
#       Bone: Intermediate, start: (-165.056, 120.194, -42.359), end: (-149.626, 122.356, -46.9567), direction: (0.949832, 0.133098, -0.283027)
#       Bone: Distal, start: (-149.626, 122.356, -46.9567), end: (-139.317, 122.557, -44.552), direction: (0.973683, 0.0190195, 0.227114)
#
# Frame id: 592, timestamp: 988237073184, hands: 1, fingers: 5
# Frame id: 592, timestamp: 988237073184, hands: 1, fingers: 5  Left hand, id 3, position: (-154.778, 142.807, -8.57016)
#
#   pitch: 17.945853 degrees, roll: 73.459963 degrees, yaw: -15.639011 degrees
#   Left hand, id 3, position: (-154.778, 142.807, -8.57016)
#   Arm direction: (0.587571, -0.14816, -0.795493), wrist position: (-151.904, 122.027, 53.308), elbow position: (-290.715, 157.029, 241.239)
#     Thumb finger, id: 30, length: 37.972485mm, width: 17.718380mm
#       Bone: Metacarpal, start: (-135.818, 142.59, 37.9039), end: (-135.818, 142.59, 37.9039), direction: (0, 0, 0)
#       Bone: Proximal, start: (-135.818, 142.59, 37.9039), end: (-122.245, 171.854, 4.46014), direction: (0.29212, 0.629787, -0.719746)
#       Bone: Intermediate, start: (-122.245, 171.854, 4.46014), end: (-113.517, 179.404, -18.0591), direction: (0.344902, 0.298369, -0.889954)
#       Bone: Distal, start: (-113.517, 179.404, -18.0591), end: (-107.915, 177.438, -33.4032), direction: (0.340532, -0.119455, -0.932614)
#     Index finger, id: 31, length: 45.038574mm, width: 16.924597mm
#       Bone: Metacarpal, start: (-151.616, 142.328, 35.872), end: (-155.444, 168.25, -22.9257), direction: (-0.0594683, 0.402688, -0.913404)
#       Bone: Proximal, start: (-155.444, 168.25, -22.9257), end: (-143.582, 169.615, -49.321), direction: (0.40946, 0.0471348, -0.91111)
#       Bone: Intermediate, start: (-143.582, 169.615, -49.321), end: (-126.689, 163.305, -54.5351), direction: (0.899921, -0.336146, -0.277757)
#       Bone: Distal, start: (-126.689, 163.305, -54.5351), end: (-113.798, 155.814, -51.0952), direction: (0.842481, -0.489574, 0.224818)
#     Middle finger, id: 32, length: 53.811378mm, width: 16.622204mm
#       Bone: Metacarpal, start: (-156.728, 136.476, 31.5511), end: (-163.466, 153.669, -26.6348), direction: (-0.110367, 0.281638, -0.953152)
#       Bone: Proximal, start: (-163.466, 153.669, -26.6348), end: (-149.827, 152.898, -56.425), direction: (0.416156, -0.0235198, -0.908989)
#       Bone: Intermediate, start: (-149.827, 152.898, -56.425), end: (-127.018, 146.141, -60.3407), direction: (0.946081, -0.280273, -0.162416)
#       Bone: Distal, start: (-127.018, 146.141, -60.3407), end: (-112.242, 139.456, -54.3392), direction: (0.854467, -0.386582, 0.347045)
#     Ring finger, id: 33, length: 43.830299mm, width: 15.817080mm
#       Bone: Metacarpal, start: (-159.026, 126.154, 27.0351), end: (-167.846, 133.9, -26.5019), direction: (-0.160927, 0.14133, -0.976795)
#       Bone: Proximal, start: (-167.846, 133.9, -26.5019), end: (-155.96, 135.291, -55.8875), direction: (0.37462, 0.0438556, -0.926141)
#       Bone: Intermediate, start: (-155.96, 135.291, -55.8875), end: (-139.299, 133.514, -61.3783), direction: (0.944916, -0.100788, -0.31141)
#       Bone: Distal, start: (-139.299, 133.514, -61.3783), end: (-126.477, 131.046, -58.2763), direction: (0.955373, -0.183941, 0.231145)
#     Pinky finger, id: 34, length: 36.778950mm, width: 14.049967mm
#       Bone: Metacarpal, start: (-154.465, 115.404, 27.004), end: (-166.725, 116.411, -22.2184), direction: (-0.241628, 0.0198476, -0.970166)
#       Bone: Proximal, start: (-166.725, 116.411, -22.2184), end: (-160.319, 118.986, -43.1514), direction: (0.290619, 0.116846, -0.949678)
#       Bone: Intermediate, start: (-160.319, 118.986, -43.1514), end: (-145.126, 120.567, -50.0594), direction: (0.906255, 0.0943262, -0.412072)
#       Bone: Distal, start: (-145.126, 120.567, -50.0594), end: (-133.502, 120.601, -48.9176), direction: (0.995206, 0.00287081, 0.0977585)
#
# Frame id: 593, timestamp: 988237082027, hands: 1, fingers: 5
#   Left hand, id 3, position: (-146.553, 141.805, -8.72388)
#   pitch: 18.213623 degrees, roll: 70.857749 degrees, yaw: -13.421577 degrees
#   Arm direction: (0.608315, -0.139161, -0.781401), wrist position: (-146.221, 120.804, 53.1999), elbow position: (-289.865, 153.664, 237.715)
#     Thumb finger, id: 30, length: 38.720467mm, width: 17.710052mm
#       Bone: Metacarpal, start: (-128.731, 140.867, 38.1653), end: (-128.731, 140.867, 38.1653), direction: (0, 0, 0)
#       Bone: Proximal, start: (-128.731, 140.867, 38.1653), end: (-113.255, 170.642, 4.674), direction: (0.326432, 0.62803, -0.706414)
#       Bone: Intermediate, start: (-113.255, 170.642, 4.674), end: (-103.433, 178.766, -17.7319), direction: (0.381026, 0.315159, -0.869192)
#       Bone: Distal, start: (-103.433, 178.766, -17.7319), end: (-96.9735, 177.767, -33.2175), direction: (0.384298, -0.0594678, -0.921292)
#     Index finger, id: 31, length: 45.838860mm, width: 16.916641mm
#       Bone: Metacarpal, start: (-144.418, 141.569, 35.7898), end: (-145.622, 167.338, -23.1542), direction: (-0.018713, 0.400497, -0.916107)
#       Bone: Proximal, start: (-145.622, 167.338, -23.1542), end: (-134.037, 169.167, -49.5247), direction: (0.401406, 0.0634019, -0.913703)
#       Bone: Intermediate, start: (-134.037, 169.167, -49.5247), end: (-117.142, 163.108, -56.4654), direction: (0.877939, -0.314867, -0.360668)
#       Bone: Distal, start: (-117.142, 163.108, -56.4654), end: (-103.496, 155.273, -55.0709), direction: (0.863841, -0.49597, 0.0882729)
#     Middle finger, id: 32, length: 54.032486mm, width: 16.614389mm
#       Bone: Metacarpal, start: (-149.76, 135.806, 31.4294), end: (-154.289, 152.997, -26.9403), direction: (-0.074224, 0.281748, -0.956613)
#       Bone: Proximal, start: (-154.289, 152.997, -26.9403), end: (-141.254, 151.426, -56.5315), direction: (0.402653, -0.0485391, -0.914065)
#       Bone: Intermediate, start: (-141.254, 151.426, -56.5315), end: (-118.818, 143.472, -60.9837), direction: (0.926464, -0.32843, -0.183842)
#       Bone: Distal, start: (-118.818, 143.472, -60.9837), end: (-103.818, 135.815, -55.5376), direction: (0.847447, -0.432617, 0.307695)
#     Ring finger, id: 33, length: 44.159794mm, width: 15.809646mm
#       Bone: Metacarpal, start: (-152.505, 125.413, 26.8301), end: (-159.664, 133.292, -26.9086), direction: (-0.130681, 0.143825, -0.980937)
#       Bone: Proximal, start: (-159.664, 133.292, -26.9086), end: (-148.693, 134.578, -56.2975), direction: (0.349424, 0.0409676, -0.936068)
#       Bone: Intermediate, start: (-148.693, 134.578, -56.2975), end: (-132.374, 132.421, -62.7859), direction: (0.922317, -0.121904, -0.366702)
#       Bone: Distal, start: (-132.374, 132.421, -62.7859), end: (-118.947, 129.23, -60.5286), direction: (0.960135, -0.228225, 0.161411)
#     Pinky finger, id: 34, length: 36.573994mm, width: 14.043363mm
#       Bone: Metacarpal, start: (-148.35, 114.469, 26.8242), end: (-159.359, 115.801, -22.6607), direction: (-0.217086, 0.0262566, -0.975799)
#       Bone: Proximal, start: (-159.359, 115.801, -22.6607), end: (-154.239, 118.018, -43.7128), direction: (0.235083, 0.10181, -0.966628)
#       Bone: Intermediate, start: (-154.239, 118.018, -43.7128), end: (-139.781, 118.808, -51.826), direction: (0.871089, 0.0476172, -0.488811)
#       Bone: Distal, start: (-139.781, 118.808, -51.826), end: (-127.995, 118.216, -51.764), direction: (0.998725, -0.0502048, 0.00525607)
#
# Frame id: 594, timestamp: 988237090641, hands: 1, fingers: 5
#   Left hand, id 3, position: (-137.91, 140.454, -9.22769)
#   pitch: 18.536213 degrees, roll: 69.022191 degrees, yaw: -11.136198 degrees
# Frame id: 594, timestamp: 988237090641, hands: 1, fingers: 5
#   Arm direction: (0.624888, -0.129638, -0.769876), wrist position: (-140.074, 119.105, 52.7018), elbow position: (-287.796, 149.751, 234.699)
#   Left hand, id 3, position: (-137.91, 140.454, -9.22769)    Thumb finger, id: 30, length: 39.147728mm, width: 17.729828mm
#
#       Bone: Metacarpal, start: (-121.511, 138.824, 38.1826), end: (-121.511, 138.824, 38.1826), direction: (0, 0, 0)
#       Bone: Proximal, start: (-121.511, 138.824, 38.1826), end: (-104.431, 168.927, 5.5547), direction: (0.359085, 0.632872, -0.685952)
#       Bone: Intermediate, start: (-104.431, 168.927, 5.5547), end: (-93.7657, 177.634, -16.5368), direction: (0.409731, 0.334484, -0.84867)
#       Bone: Distal, start: (-93.7657, 177.634, -16.5368), end: (-86.7813, 177.13, -32.0661), direction: (0.410001, -0.0295573, -0.911606)
#     Index finger, id: 31, length: 45.756516mm, width: 16.935532mm
#       Bone: Metacarpal, start: (-137.043, 140.234, 35.3694), end: (-135.641, 166.062, -23.6229), direction: (0.02176, 0.400966, -0.915835)
#       Bone: Proximal, start: (-135.641, 166.062, -23.6229), end: (-124.235, 168.469, -49.7915), direction: (0.398146, 0.0840114, -0.913467)
#       Bone: Intermediate, start: (-124.235, 168.469, -49.7915), end: (-107.614, 162.799, -57.5622), direction: (0.865507, -0.295232, -0.404643)
#       Bone: Distal, start: (-107.614, 162.799, -57.5622), end: (-93.8059, 154.963, -57.1614), direction: (0.869428, -0.493415, 0.0252355)
#     Middle finger, id: 32, length: 53.568748mm, width: 16.632942mm
#       Bone: Metacarpal, start: (-142.462, 134.547, 30.8972), end: (-144.705, 151.911, -27.6251), direction: (-0.0367249, 0.284255, -0.958045)
#       Bone: Proximal, start: (-144.705, 151.911, -27.6251), end: (-132.345, 150.168, -57.0542), direction: (0.386648, -0.0545143, -0.920615)
#       Bone: Intermediate, start: (-132.345, 150.168, -57.0542), end: (-110.446, 141.847, -62.1754), direction: (0.913231, -0.346985, -0.213565)
#       Bone: Distal, start: (-110.446, 141.847, -62.1754), end: (-95.4676, 133.835, -57.3106), direction: (0.847697, -0.453437, 0.275327)
#     Ring finger, id: 33, length: 43.546383mm, width: 15.827298mm
#       Bone: Metacarpal, start: (-145.487, 124.208, 26.1904), end: (-150.823, 132.347, -27.7833), direction: (-0.0972961, 0.148415, -0.984127)
#       Bone: Proximal, start: (-150.823, 132.347, -27.7833), end: (-140.732, 133.691, -57.0184), direction: (0.325971, 0.0433876, -0.944384)
#       Bone: Intermediate, start: (-140.732, 133.691, -57.0184), end: (-125.047, 131.357, -64.2001), direction: (0.901012, -0.134074, -0.412556)
#       Bone: Distal, start: (-125.047, 131.357, -64.2001), end: (-111.695, 128.029, -62.6757), direction: (0.964425, -0.240332, 0.110111)
#     Pinky finger, id: 34, length: 36.105312mm, width: 14.059044mm
#       Bone: Metacarpal, start: (-141.718, 113.125, 26.2314), end: (-151.258, 114.85, -23.6031), direction: (-0.187912, 0.0339732, -0.981598)
#       Bone: Proximal, start: (-151.258, 114.85, -23.6031), end: (-146.593, 116.855, -44.5381), direction: (0.216584, 0.0930516, -0.971819)
#       Bone: Intermediate, start: (-146.593, 116.855, -44.5381), end: (-132.64, 117.308, -53.0524), direction: (0.853287, 0.0277616, -0.520703)
#       Bone: Distal, start: (-132.64, 117.308, -53.0524), end: (-121.015, 116.42, -53.4511), direction: (0.996513, -0.0761209, -0.0341752)
# Frame id: 595, timestamp: 988237101291, hands: 1, fingers: 5
#   Left hand, id 3, position: (-129.498, 139.613, -9.95148)
#   pitch: 18.965074 degrees, roll: 66.835663 degrees, yaw: -8.623279 degrees
#   Arm direction: (0.639285, -0.121206, -0.759357), wrist position: (-134.373, 117.886, 51.8824), elbow position: (-285.706, 146.578, 231.639)
#     Thumb finger, id: 30, length: 39.469208mm, width: 17.754118mm
#       Bone: Metacarpal, start: (-114.599, 137.213, 37.9248), end: (-114.599, 137.213, 37.9248), direction: (0, 0, 0)
#       Bone: Proximal, start: (-114.599, 137.213, 37.9248), end: (-95.5256, 166.813, 6.02626), direction: (0.401434, 0.622997, -0.671361)
#       Bone: Intermediate, start: (-95.5256, 166.813, 6.02626), end: (-83.8319, 175.965, -15.6626), direction: (0.44488, 0.348172, -0.825141)
#       Bone: Distal, start: (-83.8319, 175.965, -15.6626), end: (-76.2927, 176.061, -31.0355), direction: (0.44031, 0.00558045, -0.897828)
#     Index finger, id: 31, length: 45.587234mm, width: 16.958735mm
#       Bone: Metacarpal, start: (-129.958, 139.334, 34.7733), end: (-125.686, 165.225, -24.1494), direction: (0.0662175, 0.401404, -0.913504)
#       Bone: Proximal, start: (-125.686, 165.225, -24.1494), end: (-114.19, 167.901, -50.0037), direction: (0.404495, 0.0941318, -0.909683)
#       Bone: Intermediate, start: (-114.19, 167.901, -50.0037), end: (-97.8473, 162.209, -58.2635), direction: (0.852268, -0.296821, -0.43074)
#       Bone: Distal, start: (-97.8473, 162.209, -58.2635), end: (-84.1403, 154.263, -58.0474), direction: (0.865058, -0.501486, 0.0136386)
#     Middle finger, id: 32, length: 53.306400mm, width: 16.655731mm
#       Bone: Metacarpal, start: (-135.493, 133.807, 30.0604), end: (-135.238, 151.384, -28.5283), direction: (0.0041771, 0.28734, -0.95782)
#       Bone: Proximal, start: (-135.238, 151.384, -28.5283), end: (-123.204, 149.364, -57.8551), direction: (0.378844, -0.0635786, -0.923274)
#       Bone: Intermediate, start: (-123.204, 149.364, -57.8551), end: (-101.854, 140.535, -63.6428), direction: (0.89641, -0.370675, -0.243)
#       Bone: Distal, start: (-101.854, 140.535, -63.6428), end: (-86.9581, 132.095, -59.2668), direction: (0.842936, -0.477634, 0.247639)
#     Ring finger, id: 33, length: 43.662407mm, width: 15.848983mm
#       Bone: Metacarpal, start: (-138.853, 123.569, 25.241), end: (-142.216, 132.039, -28.9171), direction: (-0.0612378, 0.154221, -0.986137)
#       Bone: Proximal, start: (-142.216, 132.039, -28.9171), end: (-132.632, 133.47, -58.0533), direction: (0.312145, 0.0466104, -0.94889)
#       Bone: Intermediate, start: (-132.632, 133.47, -58.0533), end: (-117.046, 130.898, -65.8535), direction: (0.884669, -0.146019, -0.442762)
#       Bone: Distal, start: (-117.046, 130.898, -65.8535), end: (-103.675, 127.299, -64.8069), direction: (0.962888, -0.259162, 0.0753766)
#     Pinky finger, id: 34, length: 35.784508mm, width: 14.078306mm
#       Bone: Metacarpal, start: (-135.532, 112.326, 25.2978), end: (-143.494, 114.547, -24.8639), direction: (-0.15662, 0.0436931, -0.986692)
#       Bone: Proximal, start: (-143.494, 114.547, -24.8639), end: (-139.415, 116.429, -45.8586), direction: (0.189968, 0.0876206, -0.977873)
#       Bone: Intermediate, start: (-139.415, 116.429, -45.8586), end: (-126.1, 116.734, -55.0546), direction: (0.822686, 0.0188766, -0.568182)
#       Bone: Distal, start: (-126.1, 116.734, -55.0546), end: (-114.677, 115.775, -56.1118), direction: (0.992282, -0.0833305, -0.091828)
#
# Frame id: 596, timestamp: 988237107918, hands: 1, fingers: 5
#   Left hand, id 3, position: (-121.302, 138.343, -10.1325)
#   pitch: 19.367012 degrees, roll: 65.640434 degrees, yaw: -5.896038 degrees
# Frame id: 596, timestamp: 988237107918, hands: 1, fingers: 5
#   Left hand, id 3, position: (-121.302, 138.343, -10.1325)
#   Arm direction: (0.652337, -0.109931, -0.749915), wrist position: (-128.972, 116.188, 51.3937), elbow position: (-283.473, 142.224, 229.005)
#     Thumb finger, id: 30, length: 39.767307mm, width: 17.763197mm
#       Bone: Metacarpal, start: (-108.368, 135.346, 38.2337), end: (-108.368, 135.346, 38.2337), direction: (0, 0, 0)
#       Bone: Proximal, start: (-108.368, 135.346, 38.2337), end: (-86.6506, 163.751, 7.18578), direction: (0.458616, 0.599835, -0.655644)
#       Bone: Intermediate, start: (-86.6506, 163.751, 7.18578), end: (-73.6044, 172.279, -14.1405), direction: (0.493899, 0.32284, -0.807365)
#       Bone: Distal, start: (-73.6044, 172.279, -14.1405), end: (-65.3326, 172.001, -29.379), direction: (0.477011, -0.0160252, -0.878751)
#     Index finger, id: 31, length: 45.623856mm, width: 16.967407mm
#       Bone: Metacarpal, start: (-123.485, 137.942, 34.5803), end: (-116.246, 164.023, -24.0039), direction: (0.112185, 0.404144, -0.90779)
#       Bone: Proximal, start: (-116.246, 164.023, -24.0039), end: (-104.137, 166.874, -49.4196), direction: (0.427917, 0.100732, -0.898187)
#       Bone: Intermediate, start: (-104.137, 166.874, -49.4196), end: (-87.8099, 161.162, -57.8488), direction: (0.848512, -0.296862, -0.438063)
#       Bone: Distal, start: (-87.8099, 161.162, -57.8488), end: (-74.1068, 153.122, -57.9722), direction: (0.862487, -0.506019, -0.00777043)
#     Middle finger, id: 32, length: 52.901020mm, width: 16.664248mm
#       Bone: Metacarpal, start: (-128.94, 132.523, 29.5487), end: (-125.944, 150.392, -28.9079), direction: (0.0489645, 0.291975, -0.955172)
#       Bone: Proximal, start: (-125.944, 150.392, -28.9079), end: (-114.14, 148.328, -58.1916), direction: (0.373065, -0.0652417, -0.925508)
#       Bone: Intermediate, start: (-114.14, 148.328, -58.1916), end: (-93.2776, 139.547, -65.022), direction: (0.88239, -0.371381, -0.288901)
#       Bone: Distal, start: (-93.2776, 139.547, -65.022), end: (-78.399, 131.082, -61.6253), direction: (0.852551, -0.48505, 0.194636)
#     Ring finger, id: 33, length: 43.826294mm, width: 15.857088mm
#       Bone: Metacarpal, start: (-132.357, 122.347, 24.6372), end: (-133.387, 131.181, -29.5858), direction: (-0.0187465, 0.160767, -0.986814)
#       Bone: Proximal, start: (-133.387, 131.181, -29.5858), end: (-124.604, 133.627, -58.7902), direction: (0.287095, 0.0799403, -0.954561)
#       Bone: Intermediate, start: (-124.604, 133.627, -58.7902), end: (-109.357, 131.528, -67.8095), direction: (0.854696, -0.117677, -0.505616)
#       Bone: Distal, start: (-109.357, 131.528, -67.8095), end: (-95.9676, 127.858, -67.9263), direction: (0.964395, -0.264331, -0.00841139)
#     Pinky finger, id: 34, length: 35.868004mm, width: 14.085505mm
#       Bone: Metacarpal, start: (-129.568, 110.977, 24.7595), end: (-135.513, 113.662, -25.6848), direction: (-0.116884, 0.0527891, -0.991742)
#       Bone: Proximal, start: (-135.513, 113.662, -25.6848), end: (-132.008, 116.129, -46.9096), direction: (0.161839, 0.113953, -0.980216)
#       Bone: Intermediate, start: (-132.008, 116.129, -46.9096), end: (-119.587, 116.84, -57.3685), direction: (0.764223, 0.0436882, -0.643471)
#       Bone: Distal, start: (-119.587, 116.84, -57.3685), end: (-108.439, 116.015, -59.6691), direction: (0.976801, -0.072262, -0.201587)
#
# Frame id: 597, timestamp: 988237117625, hands: 1, fingers: 5
#   Left hand, id 3, position: (-113.109, 137.282, -10.3853)
#   pitch: 19.687015 degrees, roll: 64.638705 degrees, yaw: -3.489932 degrees
#   Arm direction: (0.663907, -0.102943, -0.740696), wrist position: (-123.21, 114.867, 50.7057), elbow position: (-280.318, 139.227, 225.986)
#     Thumb finger, id: 30, length: 39.455032mm, width: 17.748167mm
#       Bone: Metacarpal, start: (-101.899, 133.858, 38.3176), end: (-101.899, 133.858, 38.3176), direction: (0, 0, 0)
#       Bone: Proximal, start: (-101.899, 133.858, 38.3176), end: (-77.7868, 160.745, 8.41285), direction: (0.514236, 0.573415, -0.637775)
#       Bone: Intermediate, start: (-77.7868, 160.745, 8.41285), end: (-63.5881, 168.626, -12.148), direction: (0.541925, 0.300798, -0.784753)
#       Bone: Distal, start: (-63.5881, 168.626, -12.148), end: (-54.707, 168.098, -26.8844), direction: (0.515932, -0.0306863, -0.85608)
#     Index finger, id: 31, length: 45.987431mm, width: 16.953049mm
#       Bone: Metacarpal, start: (-116.751, 136.87, 34.1812), end: (-106.938, 163.029, -23.9317), direction: (0.152177, 0.405698, -0.90125)
#       Bone: Proximal, start: (-106.938, 163.029, -23.9317), end: (-93.9922, 165.953, -48.9285), direction: (0.457429, 0.103296, -0.883226)
#       Bone: Intermediate, start: (-93.9922, 165.953, -48.9285), end: (-77.5088, 160.146, -57.3567), direction: (0.849544, -0.299307, -0.434384)
#       Bone: Distal, start: (-77.5088, 160.146, -57.3567), end: (-63.7052, 151.771, -57.6389), direction: (0.854816, -0.518637, -0.017477)
#     Middle finger, id: 32, length: 52.861870mm, width: 16.650146mm
#       Bone: Metacarpal, start: (-122.193, 131.526, 28.9051), end: (-116.799, 149.574, -29.2696), direction: (0.0882195, 0.29515, -0.951369)
#       Bone: Proximal, start: (-116.799, 149.574, -29.2696), end: (-105.08, 147.65, -58.6716), direction: (0.369564, -0.0606772, -0.927222)
#       Bone: Intermediate, start: (-105.08, 147.65, -58.6716), end: (-84.5341, 139.013, -66.5312), direction: (0.869385, -0.365463, -0.332577)
#       Bone: Distal, start: (-84.5341, 139.013, -66.5312), end: (-69.6044, 130.502, -64.008), direction: (0.859544, -0.48998, 0.145271)
#     Ring finger, id: 33, length: 44.109200mm, width: 15.843671mm
#       Bone: Metacarpal, start: (-125.698, 121.353, 23.8902), end: (-124.665, 130.445, -30.243), direction: (0.0188197, 0.165592, -0.986015)
#       Bone: Proximal, start: (-124.665, 130.445, -30.243), end: (-116.713, 134.05, -59.7919), direction: (0.258082, 0.117015, -0.95901)
#       Bone: Intermediate, start: (-116.713, 134.05, -59.7919), end: (-102.021, 132.586, -70.1301), direction: (0.815126, -0.0812177, -0.573562)
#       Bone: Distal, start: (-102.021, 132.586, -70.1301), end: (-88.6441, 129.197, -71.5107), direction: (0.964551, -0.244399, -0.0995481)
#     Pinky finger, id: 34, length: 36.372482mm, width: 14.073586mm
#       Bone: Metacarpal, start: (-123.234, 109.853, 24.0986), end: (-127.371, 112.892, -26.4628), direction: (-0.0814016, 0.0598028, -0.994886)
#       Bone: Proximal, start: (-127.371, 112.892, -26.4628), end: (-124.546, 116.282, -48.0604), direction: (0.128144, 0.153777, -0.979761)
#       Bone: Intermediate, start: (-124.546, 116.282, -48.0604), end: (-112.983, 117.731, -59.7847), direction: (0.699473, 0.0876532, -0.709264)
#       Bone: Distal, start: (-112.983, 117.731, -59.7847), end: (-102.106, 117.242, -63.3424), direction: (0.949591, -0.042663, -0.310576)
#
# Frame id: 597, timestamp: 988237117625, hands: 1, fingers: 5
#   Left hand, id 3, position: (-113.109, 137.282, -10.3853)Frame id: 598, timestamp: 988237130672, hands: 1, fingers: 5
#
#   Left hand, id 3, position: (-104.407, 135.923, -10.3808)
#   pitch: 20.067287 degrees, roll: 63.365544 degrees, yaw: -1.280984 degrees
#   Arm direction: (0.675266, -0.0980437, -0.731029), wrist position: (-116.759, 113.264, 50.2314), elbow position: (-276.478, 136.454, 223.14)
#     Thumb finger, id: 30, length: 39.722778mm, width: 17.739618mm
#       Bone: Metacarpal, start: (-94.6916, 131.953, 38.582), end: (-94.6916, 131.953, 38.582), direction: (0, 0, 0)
#       Bone: Proximal, start: (-94.6916, 131.953, 38.582), end: (-68.5516, 157.712, 9.33568), direction: (0.557031, 0.548913, -0.623226)
#       Bone: Intermediate, start: (-68.5516, 157.712, 9.33568), end: (-53.313, 165.63, -10.6568), direction: (0.578196, 0.300433, -0.75857)
#       Bone: Distal, start: (-53.313, 165.63, -10.6568), end: (-43.6618, 165.649, -25.087), direction: (0.555938, 0.0010943, -0.831223)
#     Index finger, id: 31, length: 46.198082mm, width: 16.944883mm
#       Bone: Metacarpal, start: (-109.303, 135.475, 34.0399), end: (-97.1228, 161.69, -23.5634), direction: (0.18899, 0.406749, -0.893777)
#       Bone: Proximal, start: (-97.1228, 161.69, -23.5634), end: (-83.4421, 164.515, -48.2163), direction: (0.482806, 0.099718, -0.870031)
#       Bone: Intermediate, start: (-83.4421, 164.515, -48.2163), end: (-66.9129, 158.354, -56.628), direction: (0.845775, -0.315287, -0.430416)
#       Bone: Distal, start: (-66.9129, 158.354, -56.628), end: (-53.2467, 149.632, -57.0102), direction: (0.842719, -0.537838, -0.0235639)
#     Middle finger, id: 32, length: 52.960953mm, width: 16.642126mm
#       Bone: Metacarpal, start: (-114.742, 130.232, 28.5417), end: (-107.181, 148.457, -29.3048), direction: (0.123712, 0.29818, -0.946459)
#       Bone: Proximal, start: (-107.181, 148.457, -29.3048), end: (-95.3258, 146.493, -58.973), direction: (0.370364, -0.0613589, -0.926858)
#       Bone: Intermediate, start: (-95.3258, 146.493, -58.973), end: (-75.0906, 137.856, -67.9226), direction: (0.851947, -0.363606, -0.376797)
#       Bone: Distal, start: (-75.0906, 137.856, -67.9226), end: (-60.3018, 129.338, -66.2503), direction: (0.862386, -0.49677, 0.0975157)
#     Ring finger, id: 33, length: 44.270889mm, width: 15.836039mm
#       Bone: Metacarpal, start: (-118.431, 120.1, 23.3884), end: (-115.575, 129.465, -30.6056), direction: (0.0520522, 0.170663, -0.983954)
#       Bone: Proximal, start: (-115.575, 129.465, -30.6056), end: (-108.225, 133.814, -60.4611), direction: (0.23669, 0.140069, -0.961436)
#       Bone: Intermediate, start: (-108.225, 133.814, -60.4611), end: (-94.0024, 132.766, -71.6888), direction: (0.78359, -0.0577307, -0.61859)
#       Bone: Distal, start: (-94.0024, 132.766, -71.6888), end: (-80.8028, 129.662, -74.0179), direction: (0.959383, -0.225667, -0.169288)
#     Pinky finger, id: 34, length: 36.917408mm, width: 14.066808mm
#       Bone: Metacarpal, start: (-116.283, 108.481, 23.6509), end: (-118.851, 111.913, -26.9648), direction: (-0.050552, 0.0675559, -0.996434)
#       Bone: Proximal, start: (-118.851, 111.913, -26.9648), end: (-116.552, 115.836, -48.9472), direction: (0.102402, 0.174791, -0.979266)
#       Bone: Intermediate, start: (-116.552, 115.836, -48.9472), end: (-105.743, 117.641, -61.7355), direction: (0.641801, 0.107171, -0.759346)
#       Bone: Distal, start: (-105.743, 117.641, -61.7355), end: (-95.2332, 117.321, -66.383), direction: (0.914219, -0.0278825, -0.40426)
#
# Frame id: 599, timestamp: 988237138507, hands: 1, fingers: 5
#   Left hand, id 3, position: (-95.6624, 134.281, -9.99465)
#   pitch: 20.456220 degrees, roll: 61.329936 degrees, yaw: 1.080700 degrees
#   Arm direction: (0.688879, -0.0992353, -0.718052), wrist position: (-110.467, 111.545, 50.069), elbow position: (-273.356, 135.009, 219.856)
#     Thumb finger, id: 30, length: 39.870396mm, width: 17.734161mm
#       Bone: Metacarpal, start: (-87.3941, 129.669, 39.1403), end: (-87.3941, 129.669, 39.1403), direction: (0, 0, 0)
#       Bone: Proximal, start: (-87.3941, 129.669, 39.1403), end: (-59.5851, 154.924, 11.1573), direction: (0.593674, 0.539144, -0.59739)
#       Bone: Intermediate, start: (-59.5851, 154.924, 11.1573), end: (-43.5427, 162.688, -8.35727), direction: (0.607016, 0.293772, -0.738397)
#       Bone: Distal, start: (-43.5427, 162.688, -8.35727), end: (-33.4949, 162.624, -22.6329), direction: (0.575565, -0.0036702, -0.817748)
#     Index finger, id: 31, length: 46.417625mm, width: 16.939672mm
#       Bone: Metacarpal, start: (-101.693, 133.819, 34.2581), end: (-86.9609, 159.891, -22.7888), direction: (0.228662, 0.40466, -0.885418)
#       Bone: Proximal, start: (-86.9609, 159.891, -22.7888), end: (-72.7352, 162.636, -47.1753), direction: (0.501513, 0.0967535, -0.859723)Frame id: 599, timestamp: 988237138507, hands: 1, fingers: 5
#
#   Left hand, id 3, position: (-95.6624, 134.281, -9.99465)
#       Bone: Intermediate, start: (-72.7352, 162.636, -47.1753), end: (-56.222, 156.06, -55.5847), direction: (0.839795, -0.334435, -0.427666)
#       Bone: Distal, start: (-56.222, 156.06, -55.5847), end: (-42.7501, 146.847, -56.0287), direction: (0.825147, -0.564263, -0.0271958)
#     Middle finger, id: 32, length: 52.825661mm, width: 16.637009mm
#       Bone: Metacarpal, start: (-107.235, 128.823, 28.561), end: (-97.4169, 147.094, -28.9107), direction: (0.160689, 0.299036, -0.940615)
#       Bone: Proximal, start: (-97.4169, 147.094, -28.9107), end: (-85.9564, 145.383, -58.9573), direction: (0.355875, -0.0531373, -0.933022)
#       Bone: Intermediate, start: (-85.9564, 145.383, -58.9573), end: (-66.3184, 136.895, -69.1465), direction: (0.82873, -0.358217, -0.429984)
#       Bone: Distal, start: (-66.3184, 136.895, -69.1465), end: (-51.7205, 128.37, -68.4656), direction: (0.86283, -0.503889, 0.0402475)
#     Ring finger, id: 33, length: 44.745575mm, width: 15.831168mm
#       Bone: Metacarpal, start: (-111.275, 118.781, 23.2682), end: (-106.601, 128.361, -30.544), direction: (0.0851983, 0.17463, -0.980941)
#       Bone: Proximal, start: (-106.601, 128.361, -30.544), end: (-99.7429, 133.349, -60.7823), direction: (0.218377, 0.158815, -0.962855)
#       Bone: Intermediate, start: (-99.7429, 133.349, -60.7823), end: (-85.9872, 132.522, -72.9372), direction: (0.748603, -0.0450005, -0.661489)
#       Bone: Distal, start: (-85.9872, 132.522, -72.9372), end: (-72.8694, 129.499, -76.2137), direction: (0.946827, -0.218154, -0.236491)
#     Pinky finger, id: 34, length: 37.537453mm, width: 14.062481mm
#       Bone: Metacarpal, start: (-109.461, 107.058, 23.5471), end: (-110.524, 110.9, -27.0773), direction: (-0.0209359, 0.075661, -0.996914)
#       Bone: Proximal, start: (-110.524, 110.9, -27.0773), end: (-108.761, 115.011, -49.4336), direction: (0.0773408, 0.180314, -0.980564)
#       Bone: Intermediate, start: (-108.761, 115.011, -49.4336), end: (-98.4342, 116.766, -63.0028), direction: (0.60242, 0.102358, -0.791589)
#       Bone: Distal, start: (-98.4342, 116.766, -63.0028), end: (-88.0664, 116.315, -68.3694), direction: (0.887422, -0.0385274, -0.459346)
#
# Frame id: 600, timestamp: 988237148575, hands: 1, fingers: 5
#   Left hand, id 3, position: (-86.9508, 132.881, -9.95515)
#   pitch: 20.833356 degrees, roll: 58.999298 degrees, yaw: 3.024664 degrees
#   Arm direction: (0.70141, -0.101972, -0.705426), wrist position: (-103.826, 110.135, 49.6339), elbow position: (-269.753, 134.257, 216.511)
#     Thumb finger, id: 30, length: 40.184868mm, width: 17.742142mm
#       Bone: Metacarpal, start: (-79.738, 127.635, 39.3), end: (-79.738, 127.635, 39.3), direction: (0, 0, 0)
#       Bone: Proximal, start: (-79.738, 127.635, 39.3), end: (-50.2139, 151.754, 12.0303), direction: (0.629879, 0.51457, -0.581782)
#       Bone: Intermediate, start: (-50.2139, 151.754, 12.0303), end: (-33.1418, 159.454, -6.92201), direction: (0.640732, 0.288992, -0.711299)
#       Bone: Distal, start: (-33.1418, 159.454, -6.92201), end: (-22.4539, 159.731, -20.8831), direction: (0.607796, 0.0157598, -0.793937)
#     Index finger, id: 31, length: 46.576344mm, width: 16.947294mm
#       Bone: Metacarpal, start: (-93.7503, 132.312, 34.2322), end: (-76.8913, 158.154, -22.3616), direction: (0.261548, 0.400907, -0.87799)
#       Bone: Proximal, start: (-76.8913, 158.154, -22.3616), end: (-61.6356, 160.427, -46.3536), direction: (0.53487, 0.0797192, -0.841165)
#       Bone: Intermediate, start: (-61.6356, 160.427, -46.3536), end: (-45.133, 153.1, -54.35), direction: (0.835682, -0.371033, -0.404932)
#       Bone: Distal, start: (-45.133, 153.1, -54.35), end: (-32.1704, 143.183, -54.4356), direction: (0.794192, -0.607645, -0.00524582)
#     Middle finger, id: 32, length: 52.984276mm, width: 16.644495mm
#       Bone: Metacarpal, start: (-99.434, 127.698, 28.3591), end: (-87.8144, 145.958, -28.8085), direction: (0.190086, 0.298722, -0.935218)
#       Bone: Proximal, start: (-87.8144, 145.958, -28.8085), end: (-76.0209, 144.437, -59.1684), direction: (0.361703, -0.0466685, -0.931125)
#       Bone: Intermediate, start: (-76.0209, 144.437, -59.1684), end: (-56.7046, 135.949, -70.228), direction: (0.810871, -0.356292, -0.464268)
#       Bone: Distal, start: (-56.7046, 135.949, -70.228), end: (-42.3955, 127.337, -70.3184), direction: (0.856779, -0.515655, -0.00540965)
#     Ring finger, id: 33, length: 45.668839mm, width: 15.838292mm
#       Bone: Metacarpal, start: (-103.829, 117.804, 22.9074), end: (-97.7892, 127.572, -30.7599), direction: (0.110044, 0.177989, -0.97786)
#       Bone: Proximal, start: (-97.7892, 127.572, -30.7599), end: (-90.4699, 132.501, -61.3585), direction: (0.229839, 0.154783, -0.960841)
#       Bone: Intermediate, start: (-90.4699, 132.501, -61.3585), end: (-76.6663, 131.436, -74.0943), direction: (0.733783, -0.056619, -0.677021)
#       Bone: Distal, start: (-76.6663, 131.436, -74.0943), end: (-63.3515, 128.211, -77.8316), direction: (0.937622, -0.227159, -0.26318)
#     Pinky finger, id: 34, length: 38.609680mm, width: 14.068810mm
#       Bone: Metacarpal, start: (-102.527, 106.027, 23.1265), end: (-102.525, 110.285, -27.4988), direction: (5.13592e-05, 0.0838119, -0.996482)
#       Bone: Proximal, start: (-102.525, 110.285, -27.4988), end: (-100.818, 114.275, -50.3581), direction: (0.073344, 0.171492, -0.982451)
#       Bone: Intermediate, start: (-100.818, 114.275, -50.3581), end: (-90.5812, 115.787, -64.7286), direction: (0.578086, 0.085361, -0.811498)
#       Bone: Distal, start: (-90.5812, 115.787, -64.7286), end: (-80.1689, 115.201, -70.7362), direction: (0.865139, -0.0486927, -0.499163)
#
# Frame id: 601, timestamp: 988237159940, hands: 1, fingers: 5
# Frame id: 601, timestamp: 988237159940, hands: 1, fingers: 5
#   Left hand, id 3, position: (-77.9969, 131.218, -9.72844)
#   Left hand, id 3, position: (-77.9969, 131.218, -9.72844)
#   pitch: 21.027924 degrees, roll: 55.651433 degrees, yaw: 5.701999 degrees
#   Arm direction: (0.711784, -0.107833, -0.694072), wrist position: (-97.6077, 108.844, 49.2736), elbow position: (-266.066, 134.365, 213.54)
#     Thumb finger, id: 30, length: 40.955975mm, width: 17.750340mm
#       Bone: Metacarpal, start: (-72.2703, 125.337, 39.6134), end: (-72.2703, 125.337, 39.6134), direction: (0, 0, 0)
#       Bone: Proximal, start: (-72.2703, 125.337, 39.6134), end: (-40.5851, 148.41, 13.5702), direction: (0.673302, 0.490307, -0.553411)
#       Bone: Intermediate, start: (-40.5851, 148.41, 13.5702), end: (-22.3073, 155.918, -4.95649), direction: (0.674797, 0.277158, -0.683983)
#       Bone: Distal, start: (-22.3073, 155.918, -4.95649), end: (-10.9323, 156.252, -18.9186), direction: (0.631513, 0.0185784, -0.775143)
#     Index finger, id: 31, length: 46.292099mm, width: 16.955124mm
#       Bone: Metacarpal, start: (-85.8358, 130.752, 34.3397), end: (-66.0994, 155.875, -21.6785), direction: (0.306047, 0.389573, -0.868659)
#       Bone: Proximal, start: (-66.0994, 155.875, -21.6785), end: (-50.1156, 157.87, -45.0703), direction: (0.562783, 0.0702435, -0.823614)
#       Bone: Intermediate, start: (-50.1156, 157.87, -45.0703), end: (-33.856, 150.084, -52.8558), direction: (0.828007, -0.396503, -0.396471)
#       Bone: Distal, start: (-33.856, 150.084, -52.8558), end: (-21.4426, 139.715, -52.9401), direction: (0.767462, -0.641073, -0.00521362)
#     Middle finger, id: 32, length: 52.489532mm, width: 16.652185mm
#       Bone: Metacarpal, start: (-91.639, 126.627, 28.2713), end: (-77.5819, 144.502, -28.4992), direction: (0.229858, 0.292298, -0.928293)
#       Bone: Proximal, start: (-77.5819, 144.502, -28.4992), end: (-65.4659, 143.228, -58.815), direction: (0.370837, -0.0390103, -0.927878)
#       Bone: Intermediate, start: (-65.4659, 143.228, -58.815), end: (-46.7581, 134.694, -70.2336), direction: (0.795395, -0.362836, -0.485486)
#       Bone: Distal, start: (-46.7581, 134.694, -70.2336), end: (-32.9048, 125.923, -70.83), direction: (0.844353, -0.534553, -0.0363492)
#     Ring finger, id: 33, length: 45.817692mm, width: 15.845610mm
#       Bone: Metacarpal, start: (-96.5486, 116.966, 22.6427), end: (-88.6621, 126.681, -30.8201), direction: (0.143632, 0.176944, -0.973684)
#       Bone: Proximal, start: (-88.6621, 126.681, -30.8201), end: (-80.6345, 131.614, -61.3341), direction: (0.251367, 0.154467, -0.955487)
#       Bone: Intermediate, start: (-80.6345, 131.614, -61.3341), end: (-66.8957, 130.232, -74.1778), direction: (0.728537, -0.0733226, -0.681071)
#       Bone: Distal, start: (-66.8957, 130.232, -74.1778), end: (-53.6917, 126.584, -78.1935), direction: (0.924971, -0.255533, -0.281303)
#     Pinky finger, id: 34, length: 38.706039mm, width: 14.075309mm
#       Bone: Metacarpal, start: (-96.0004, 105.166, 22.7858), end: (-94.5481, 109.729, -27.8156), direction: (0.0285748, 0.0897773, -0.995552)
#       Bone: Proximal, start: (-94.5481, 109.729, -27.8156), end: (-92.5318, 113.402, -50.7702), direction: (0.086411, 0.157381, -0.98375)
#       Bone: Intermediate, start: (-92.5318, 113.402, -50.7702), end: (-82.3839, 114.486, -65.2795), direction: (0.572063, 0.0611246, -0.817929)
#       Bone: Distal, start: (-82.3839, 114.486, -65.2795), end: (-72.0689, 113.282, -71.4464), direction: (0.854032, -0.0996716, -0.510584)
#
# Frame id: 602, timestamp: 988237167173, hands: 1, fingers: 5
#   Left hand, id 3, position: (-69.5511, 129.287, -9.09433)
#   pitch: 20.944762 degrees, roll: 51.919752 degrees, yaw: 8.371760 degrees
#   Arm direction: (0.718324, -0.120734, -0.685153), wrist position: (-91.8096, 107.731, 49.2921), elbow position: (-261.689, 136.284, 211.326)
#     Thumb finger, id: 30, length: 41.441319mm, width: 17.737024mm
#       Bone: Metacarpal, start: (-65.2965, 122.938, 40.2689), end: (-65.2965, 122.938, 40.2689), direction: (0, 0, 0)
#       Bone: Proximal, start: (-65.2965, 122.938, 40.2689), end: (-31.706, 144.852, 15.7533), direction: (0.714603, 0.466192, -0.521544)
#       Bone: Intermediate, start: (-31.706, 144.852, 15.7533), end: (-12.3796, 151.919, -2.28318), direction: (0.706283, 0.258253, -0.659143)
#       Bone: Distal, start: (-12.3796, 151.919, -2.28318), end: (-0.532441, 151.941, -16.2082), direction: (0.647994, 0.00122268, -0.761645)
#     Index finger, id: 31, length: 45.864956mm, width: 16.942406mm
#       Bone: Metacarpal, start: (-78.2413, 129.161, 34.8447), end: (-55.7024, 153.118, -20.5677), direction: (0.349767, 0.371777, -0.85991)
#       Bone: Proximal, start: (-55.7024, 153.118, -20.5677), end: (-38.9282, 154.545, -43.3892), direction: (0.591494, 0.0503133, -0.804738)
#       Bone: Intermediate, start: (-38.9282, 154.545, -43.3892), end: (-23.0915, 146.035, -50.7121), direction: (0.8158, -0.438373, -0.377226)
#       Bone: Distal, start: (-23.0915, 146.035, -50.7121), end: (-11.5567, 135.037, -50.5257), direction: (0.723688, -0.690028, 0.0116935)
#     Middle finger, id: 32, length: 51.878990mm, width: 16.639694mm
#       Bone: Metacarpal, start: (-84.2771, 125.487, 28.5723), end: (-67.8692, 142.603, -27.7503), direction: (0.268498, 0.280094, -0.92166)
#       Bone: Proximal, start: (-67.8692, 142.603, -27.7503), end: (-55.3592, 141.668, -57.8815), direction: (0.383291, -0.0286467, -0.923183)
#       Bone: Intermediate, start: (-55.3592, 141.668, -57.8815), end: (-37.4332, 133.052, -69.8139), direction: (0.772866, -0.371504, -0.514454)
# Frame id: 602, timestamp: 988237167173, hands: 1, fingers: 5
#   Left hand, id 3, position: (-69.5511, 129.287, -9.09433)
#       Bone: Distal, start: (-37.4332, 133.052, -69.8139), end: (-24.1843, 124.073, -71.135), direction: (0.825002, -0.559109, -0.082268)
#     Ring finger, id: 33, length: 45.872566mm, width: 15.833724mm
#       Bone: Metacarpal, start: (-89.7207, 116.151, 22.7541), end: (-80.0805, 125.533, -30.4379), direction: (0.175704, 0.170987, -0.96948)
#       Bone: Proximal, start: (-80.0805, 125.533, -30.4379), end: (-71.5065, 130.418, -60.8716), direction: (0.267991, 0.152703, -0.951243)
#       Bone: Intermediate, start: (-71.5065, 130.418, -60.8716), end: (-57.9849, 128.757, -73.8926), direction: (0.717508, -0.0881859, -0.690945)
#       Bone: Distal, start: (-57.9849, 128.757, -73.8926), end: (-45.026, 124.575, -78.3419), direction: (0.904605, -0.291931, -0.31059)
#     Pinky finger, id: 34, length: 38.696281mm, width: 14.064752mm
#       Bone: Metacarpal, start: (-89.9999, 104.355, 22.8231), end: (-87.1789, 109.02, -27.6728), direction: (0.055544, 0.0918429, -0.994223)
#       Bone: Proximal, start: (-87.1789, 109.02, -27.6728), end: (-84.732, 112.384, -50.61), direction: (0.104964, 0.144309, -0.98395)
#       Bone: Intermediate, start: (-84.732, 112.384, -50.61), end: (-74.6152, 112.906, -65.1521), direction: (0.57084, 0.0294619, -0.820533)
#       Bone: Distal, start: (-74.6152, 112.906, -65.1521), end: (-64.4202, 111.058, -71.4039), direction: (0.842483, -0.152698, -0.51663)
#
# Frame id: 603, timestamp: 988237176393, hands: 1, fingers: 5
#   Left hand, id 3, position: (-61.3774, 127.507, -8.31341)
#   pitch: 21.115836 degrees, roll: 48.534976 degrees, yaw: 10.241030 degrees
#   Arm direction: (0.725083, -0.134497, -0.675399), wrist position: (-85.5133, 106.505, 49.4974), elbow position: (-256.832, 138.284, 209.077)
#     Thumb finger, id: 30, length: 42.071205mm, width: 17.720598mm
#       Bone: Metacarpal, start: (-57.9902, 120.421, 41.0176), end: (-57.9902, 120.421, 41.0176), direction: (0, 0, 0)
#       Bone: Proximal, start: (-57.9902, 120.421, 41.0176), end: (-22.8312, 140.857, 17.6515), direction: (0.749635, 0.435714, -0.498197)
#       Bone: Intermediate, start: (-22.8312, 140.857, 17.6515), end: (-2.30665, 147.719, 0.289241), direction: (0.739752, 0.247337, -0.625773)
#       Bone: Distal, start: (-2.30665, 147.719, 0.289241), end: (10.3046, 147.855, -13.3888), direction: (0.677837, 0.00732137, -0.735176)
#     Index finger, id: 31, length: 45.487301mm, width: 16.926716mm
#       Bone: Metacarpal, start: (-70.4575, 127.449, 35.5836), end: (-46.0029, 150.571, -19.2995), direction: (0.379847, 0.359146, -0.852485)
#       Bone: Proximal, start: (-46.0029, 150.571, -19.2995), end: (-28.4647, 151.242, -41.5091), direction: (0.619564, 0.0237021, -0.784588)
#       Bone: Intermediate, start: (-28.4647, 151.242, -41.5091), end: (-13.0777, 141.858, -48.1871), direction: (0.800567, -0.488231, -0.347452)
#       Bone: Distal, start: (-13.0777, 141.858, -48.1871), end: (-2.50834, 130.224, -47.5192), direction: (0.671844, -0.739474, 0.0424596)
#     Middle finger, id: 32, length: 51.565231mm, width: 16.624283mm
#       Bone: Metacarpal, start: (-76.6581, 124.187, 29.1548), end: (-58.7236, 140.87, -26.7697), direction: (0.293751, 0.273253, -0.915993)
#       Bone: Proximal, start: (-58.7236, 140.87, -26.7697), end: (-45.6596, 140.019, -56.5251), direction: (0.401868, -0.0261757, -0.915323)
#       Bone: Intermediate, start: (-45.6596, 140.019, -56.5251), end: (-28.2129, 131.093, -68.8054), direction: (0.754385, -0.385944, -0.53099)
#       Bone: Distal, start: (-28.2129, 131.093, -68.8054), end: (-15.5356, 121.772, -70.472), direction: (0.801166, -0.5891, -0.105326)
#     Ring finger, id: 33, length: 46.115704mm, width: 15.819059mm
#       Bone: Metacarpal, start: (-82.5602, 115.24, 23.1278), end: (-71.8733, 124.588, -29.8173), direction: (0.194961, 0.17052, -0.965874)
#       Bone: Proximal, start: (-71.8733, 124.588, -29.8173), end: (-62.5413, 129.616, -60.0505), direction: (0.29128, 0.156942, -0.943677)
#       Bone: Intermediate, start: (-62.5413, 129.616, -60.0505), end: (-48.9667, 127.533, -73.2233), direction: (0.71334, -0.10945, -0.692219)
#       Bone: Distal, start: (-48.9667, 127.533, -73.2233), end: (-36.1343, 123.116, -77.9561), direction: (0.892816, -0.307322, -0.329292)
#     Pinky finger, id: 34, length: 38.895229mm, width: 14.051725mm
#       Bone: Metacarpal, start: (-83.7102, 103.523, 23.0179), end: (-80.135, 108.552, -27.3479), direction: (0.0704578, 0.099104, -0.99258)
#       Bone: Proximal, start: (-80.135, 108.552, -27.3479), end: (-77.261, 111.722, -50.2644), direction: (0.123283, 0.136006, -0.983008)
#       Bone: Intermediate, start: (-77.261, 111.722, -50.2644), end: (-67.0444, 111.595, -64.8909), direction: (0.572624, -0.00713986, -0.819787)
